# %% [markdown]
# # <0. 필요 패키지 설치하기>

# %% [markdown]
# # <1-1. 필요 라이브러리 불러오기>

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import glob
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# import function libraries
import numpy as np
import keras
import os, sys ,math, copy
import scipy.io as sio
import tensorflow as tf
from keras.models import Model, Sequential
from keras.engine import Layer, InputSpec
from keras.optimizers import RMSprop, SGD, Adam
from keras import initializers, regularizers, constraints
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, History
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras import backend as K
from keras.utils import np_utils
import tensorflow as tf
from tensorflow import keras

sys.setrecursionlimit(10000)

import matplotlib.pyplot as plt

# %% [markdown]
# # <1-2. 데이터 불러오기>

# %%
# 파일 경로 확인!
# train.csv 파일은 현재 실행한 CNC_network.ipynb 파일과 같은 폴더에 저장되어야 함
# 개별 생산 단위 데이터 파일 경로 설정
# CNC Virtual Data set _v2 폴더의 파일 경로 복사하여 path 의 ' '안에 붙여넣기

train_sample = pd.read_csv("train.csv", header=0, encoding='utf-8')
path = r'../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2'
all_files = glob.glob(path + "\*.csv")

# count the number of pass/fail items

train_sample_np = np.array(train_sample.copy())


# load csv file
li_df = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)    
    li_df.append(df)

# %% [markdown]
# # <2-1. 데이터 종류 확인>

# %%
train_sample
# Out:
#     No  material  feedrate  clamp_pressure tool_condition machining_finalized  \
# 0    1  aluminum         6             4.0         unworn                 yes
# 1    2  aluminum        20             4.0         unworn                 yes
# 2    3  aluminum         6             3.0         unworn                 yes
# 3    4  aluminum         6             2.5         unworn                  no
# 4    5  aluminum        20             3.0         unworn                  no
# 5    6  aluminum         6             4.0           worn                 yes
# 6    7  aluminum        20             4.0           worn                  no
# 7    8  aluminum        20             4.0           worn                 yes
# 8    9  aluminum        15             4.0           worn                 yes
# 9   10  aluminum        12             4.0           worn                 yes
# 10  11  aluminum         3             4.0         unworn                 yes
# 11  12  aluminum         3             3.0         unworn                 yes
# 12  13  aluminum         3             4.0           worn                 yes
# 13  14  aluminum         3             3.0           worn                 yes
# 14  15  aluminum         6             3.0           worn                 yes
# 15  16  aluminum        20             3.0           worn                  no
# 16  17  aluminum         3             2.5         unworn                 yes
# 17  18  aluminum         3             2.5           worn                 yes
# 18  19  aluminum        15             4.0           worn                 yes
# 19  20  aluminum        12             4.0         unworn                  no
# 20  21  aluminum         3             4.0         unworn                 yes
# 21  22  aluminum        20             3.0           worn                 yes
# 22  23  aluminum         3             4.0           worn                  no
# 23  24  aluminum         3             3.0         unworn                 yes
# 24  25  aluminum         6             2.5           worn                 yes
#
#    passed_visual_inspection
# 0                       yes
# 1                       yes
# 2                       yes
# 3                       NaN
# 4                       NaN
# 5                        no
# 6                       NaN
# 7                        no
# 8                        no
# 9                        no
# 10                      yes
# 11                      yes
# 12                      yes
# 13                      yes
# 14                      yes
# 15                      NaN
# 16                      yes
# 17                      yes
# 18                       no
# 19                      NaN
# 20                       no
# 21                      yes
# 22                      NaN
# 23                      yes
# 24                      yes

# %%
df
# Out:
#      X_ActualPosition  X_ActualVelocity  X_ActualAcceleration  X_SetPosition  \
# 0               176.0            4.9750                -1.250          176.0
# 1               176.0            5.0250                23.775          176.0
# 2               176.0            4.9750                -1.250          176.0
# 3               176.0            4.9625               -13.750          176.0
# 4               176.0            4.9750                -4.400          176.0
# ..                ...               ...                   ...            ...
# 560             179.0            3.5625                 8.150          179.0
# 561             178.5            3.5350                30.000          178.5
# 562             178.5            3.5475                17.500          178.5
# 563             178.5            3.4475                11.250          178.5
# 564             178.0            3.5625                 1.850          178.0
#
#      X_SetVelocity  X_SetAcceleration  X_CurrentFeedback  X_DCBusVoltage  \
# 0              5.0                5.0             -1.420          0.0227
# 1              5.0                5.0             -1.740          0.0224
# 2              5.0                5.0              0.180          0.0329
# 3              5.0                5.0             -0.619          0.0198
# 4              5.0                5.0             -0.779          0.0311
# ..             ...                ...                ...             ...
# 560            3.5                5.0             -0.941          0.0215
# 561            3.5                5.0             -0.780          0.0202
# 562            3.5                5.0              0.501          0.0190
# 563            3.5                5.0             -0.298          0.0193
# 564            3.5                5.0              0.340          0.0258
#
#      X_OutputCurrent  X_OutputVoltage  ...  S_CurrentFeedback  S_DCBusVoltage  \
# 0                327            0.355  ...              0.499    2.710000e-19
# 1                327            0.589  ...              0.790    2.710000e-19
# 2                327            2.190  ...             -1.300    2.710000e-19
# 3                327            1.010  ...             -3.810    2.710000e-19
# 4                327            0.372  ...              0.790    2.710000e-19
# ..               ...              ...  ...                ...             ...
# 560              328            1.790  ...              0.244    2.770000e-19
# 561              328            1.070  ...              0.244    2.770000e-19
# 562              328            0.990  ...              0.128    2.770000e-19
# 563              328            1.370  ...              0.657    2.770000e-19
# 564              328            1.090  ...              0.244    2.770000e-19
#
#      S_OutputCurrent  S_OutputVoltage  S_OutputPower  S_SystemInertia  \
# 0                327              0.0       0.000003               17
# 1                327              0.0      -0.000003               17
# 2                327              0.0      -0.000006               17
# 3                327              0.0       0.000002               17
# 4                327              0.0       0.000000               17
# ..               ...              ...            ...              ...
# 560              328              0.0      -0.000003               17
# 561              328              0.0       0.000000               17
# 562              328              0.0       0.000000               17
# 563              328              0.0      -0.000008               17
# 564              328              0.0      -0.000003               17
#
#      M_CURRENT_PROGRAM_NUMBER  M_sequence_number  M_CURRENT_FEEDRATE  \
# 0                           1                  2                  50
# 1                           1                  0                  50
# 2                           1                  0                  50
# 3                           1                  0                  50
# 4                           1                  0                  50
# ..                        ...                ...                 ...
# 560                         1                  0                  20
# 561                         1                  0                  20
# 562                         1                  0                  20
# 563                         1                  0                  20
# 564                         1                  0                  20
#
#      Machining_Process
# 0                 Prep
# 1                 Prep
# 2                 Prep
# 3                 Prep
# 4                 Prep
# ..                 ...
# 560                End
# 561                End
# 562                End
# 563                End
# 564                End
#
# [565 rows x 48 columns]

# %%
# path에 있는 25개의 개별 생산 단위 데이터 파일의 경로 확인
print(all_files)
# Out:
# ['../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_01.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_02.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_03.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_04.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_05.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_06.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_07.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_08.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_09.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_10.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_11.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_12.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_13.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_14.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_15.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_16.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_17.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_18.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_19.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_20.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_21.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_22.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_23.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_24.csv', '../dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_25.csv']

# %% [markdown]
# # <2-2 데이터 개수 확인>

# %%
# count the number of pass/fail items
nb_pass = 0
nb_pass_half = 0
nb_defective = 0
for i in range(len(train_sample_np)):
    if train_sample_np[i,5] == 'no':
        nb_defective += 1
    if train_sample_np[i,5] == 'yes' and train_sample_np[i,6] =='yes':
        nb_pass += 1
    if train_sample_np[i,5] == 'yes' and train_sample_np[i,6] == 'no':
        nb_pass_half += 1
        
print('양품 샘플 개수 : ', nb_pass)
print('공정 마쳤으나 육안검사 통과 못한 샘플 개수 : ', nb_pass_half)
print('공정 중지된 샘플 개수 : ', nb_defective)
print('전체 샘플 개수 : ', nb_pass + nb_pass_half + nb_defective)
# Out:
# 양품 샘플 개수 :  13
# 공정 마쳤으나 육안검사 통과 못한 샘플 개수 :  6
# 공정 중지된 샘플 개수 :  6
# 전체 샘플 개수 :  25

# %% [markdown]
# # < 3-1. 사용자 정의 함수 선언 >

# %%
def tool_condition(input):
    for i in range(len(input)):
        if input[i,4] == 'unworn':
            input[i,4] = 0
        else:
            input[i,4] = 1
    return input

def item_inspection(input):
    for i in range(len(input)):
        if input[i,5] == 'no':
            input[i,6] = 2
        elif input[i,5] == 'yes' and input[i,6] == 'no':
            input[i,6] = 1
        elif input[i,5] == 'yes' and input[i,6] == 'yes':
            input[i,6] = 0
    return input


def machining_process(input):
    for i in range(len(input)):
        if input[i,47] == 'Prep':
            input[i,47] = 0
        elif input[i,47] == 'Layer 1 Up':
            input[i,47] = 1
        elif input[i,47] == 'Layer 1 Down':
            input[i,47] = 2
        elif input[i,47] == 'Layer 2 Up':
            input[i,47] = 3
        elif input[i,47] == 'Layer 2 Down':
            input[i,47] = 4
        elif input[i,47] == 'Layer 3 Up':
            input[i,47] = 5
        elif input[i,47] == 'Layer 3 Down':
            input[i,47] = 6
        elif input[i,47] == 'Repositioning':
            input[i,47] = 7
        elif input[i,47] == 'End' or 'end':
            input[i,47] = 8        
        elif input[i,47] == 'Starting':
            input[i,47] = 9
    return input

# %% [markdown]
# # <3-2. 사용자 정의 함수의 사용을 통한 데이터 분류>

# %%
# Modifying train.csv for training, 
# - [tool_condition]  : unworn/worn -> 0 / 1 
# - [item_inspection] : machining_finalized & passed -> yes & yes / yes & no / no : 0 / 1 / 2
# - delete 'material' column and 'No' column

train_sample_info = np.array(train_sample_np.copy())
train_sample_info = tool_condition(train_sample_info)
train_sample_info = item_inspection(train_sample_info)
print(train_sample_info)


#[feedrate  clamp_pressure  unworn/worn  label]
# Out:
# [[1 'aluminum' 6 4.0 0 'yes' 0]
#  [2 'aluminum' 20 4.0 0 'yes' 0]
#  [3 'aluminum' 6 3.0 0 'yes' 0]
#  [4 'aluminum' 6 2.5 0 'no' 2]
#  [5 'aluminum' 20 3.0 0 'no' 2]
#  [6 'aluminum' 6 4.0 1 'yes' 1]
#  [7 'aluminum' 20 4.0 1 'no' 2]
#  [8 'aluminum' 20 4.0 1 'yes' 1]
#  [9 'aluminum' 15 4.0 1 'yes' 1]
#  [10 'aluminum' 12 4.0 1 'yes' 1]
#  [11 'aluminum' 3 4.0 0 'yes' 0]
#  [12 'aluminum' 3 3.0 0 'yes' 0]
#  [13 'aluminum' 3 4.0 1 'yes' 0]
#  [14 'aluminum' 3 3.0 1 'yes' 0]
#  [15 'aluminum' 6 3.0 1 'yes' 0]
#  [16 'aluminum' 20 3.0 1 'no' 2]
#  [17 'aluminum' 3 2.5 0 'yes' 0]
#  [18 'aluminum' 3 2.5 1 'yes' 0]
#  [19 'aluminum' 15 4.0 1 'yes' 1]
#  [20 'aluminum' 12 4.0 0 'no' 2]
#  [21 'aluminum' 3 4.0 0 'yes' 1]
#  [22 'aluminum' 20 3.0 1 'yes' 0]
#  [23 'aluminum' 3 4.0 1 'no' 2]
#  [24 'aluminum' 3 3.0 0 'yes' 0]
#  [25 'aluminum' 6 2.5 1 'yes' 0]]

# %%
train_sample_info = np.delete(train_sample_info,5,1)
train_sample_info = np.delete(train_sample_info,0,1)
train_sample_info = np.delete(train_sample_info,0,1)
print(train_sample_info)
# Out:
# [[6 4.0 0 0]
#  [20 4.0 0 0]
#  [6 3.0 0 0]
#  [6 2.5 0 2]
#  [20 3.0 0 2]
#  [6 4.0 1 1]
#  [20 4.0 1 2]
#  [20 4.0 1 1]
#  [15 4.0 1 1]
#  [12 4.0 1 1]
#  [3 4.0 0 0]
#  [3 3.0 0 0]
#  [3 4.0 1 0]
#  [3 3.0 1 0]
#  [6 3.0 1 0]
#  [20 3.0 1 2]
#  [3 2.5 0 0]
#  [3 2.5 1 0]
#  [15 4.0 1 1]
#  [12 4.0 0 2]
#  [3 4.0 0 1]
#  [20 3.0 1 0]
#  [3 4.0 1 2]
#  [3 3.0 0 0]
#  [6 2.5 1 0]]

# %%
k  = 0
li_pass = []
li_pass_half = []
li_fail = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)      
    
    if train_sample_info[k,3] == 0:
        li_pass.append(df)        
    elif train_sample_info[k,3] == 1:
        li_pass_half.append(df)        
    else :
        li_fail.append(df)
        
    k += 1
    
frame01 = pd.concat(li_pass, axis=0, ignore_index=True)
frame02 = pd.concat(li_pass_half, axis=0, ignore_index=True)
frame03 = pd.concat(li_fail, axis=0, ignore_index=True)

data_pass = np.array(frame01.copy())
data_pass_half = np.array(frame02.copy())
data_fail = np.array(frame03.copy())


print('공정완료 및 육안검사 합격한 전체 데이터 수 : ',len(data_pass))
print('공정완료 및 육안검사 불합격한 전체 데이터 수 : ',len(data_pass_half))
print('공정 미완료한 전체 데이터 수 : ',len(data_fail))
# Out:
# 공정완료 및 육안검사 합격한 전체 데이터 수 :  22645
# 공정완료 및 육안검사 불합격한 전체 데이터 수 :  6175
# 공정 미완료한 전체 데이터 수 :  3228

# %%
print(data_pass.shape)
print(data_pass_half.shape)
print(data_fail.shape)
# Out:
# (22645, 48)
# (6175, 48)
# (3228, 48)

# %%
# Modifying experiment data 
#  - machining_process : From "Prep" to "End" -> 0~9
data_pass = machining_process(data_pass)
data_pass_half = machining_process(data_pass_half)
data_fail = machining_process(data_fail)

# %% [markdown]
# # <3-3. 데이터셋 구성>

# %%
# label 0/1 --> data01 / data02+data03

data01 = data_pass[0:3228+6175,:]
data02 = data_pass_half[0:6175,:]
data03 = data_fail[0:3228,:]

data = np.concatenate((data01,data02),axis=0);
data = np.concatenate((data,data03),axis=0);

data_all= data_pass[3228+6175:22645,:]

# %%
print((data))
print(data.shape)
print(data_all.shape)
# Out:
# [[202.0 4.0 4.0 ... 0 50 8]
#  [202.0 -6.8 -346.0 ... 4 50 0]
#  [200.0 -13.8 -2.25 ... 7 50 0]
#  ...
#  [155.0 9.875 -64.6 ... 0 50 8]
#  [155.5 9.95 -52.125 ... 0 50 8]
#  [156.0 10.1 76.125 ... 0 50 8]]
# (18806, 48)
# (13242, 48)

# %% [markdown]
# # <3-4. 데이터 정제 (2차 전처리)>

# %%
# 2차 전처리 진행, MinMaxScaler 사용
sc = MinMaxScaler()
X_train = sc.fit_transform(data)
X_train = np.array(X_train)
X_test = sc.fit_transform(data_all)
X_test = np.array(X_test)

# %% [markdown]
# # <4-1. 라벨 데이터 제작>

# %%
# 라벨 데이터 생성

Y_train = np.zeros((len(X_train),1),dtype='int')
Y_test = np.zeros((len(X_test),1),dtype='int')
l = int(Y_train.shape[0]/2)

Y_train[0:l,:] = 0
Y_train[l:l*2,:] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6676/4231030410.py in <module>
#       1 # 라벨 데이터 생성
#       2
# ----> 3 Y_train = np.zeros((len(X_train),1),dtype='int')
#       4 Y_test = np.zeros((len(X_test),1),dtype='int')
#       5 l = int(Y_train.shape[0]/2)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # <5-1. 학습/검증/평가 데이터 구성>

# %%
# 뒤의 <7-1. AI 모델 훈련> 항목에 포함되어 있음

# %% [markdown]
# # <6-1. AI 모델 파라미터 설정>

# %%
nb_classes = 2
batch_size = 1024
epochs = 300
lr = 1e-4

# %% [markdown]
# # <6-2. 데이터셋 준비>

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

Y_train = np_utils.to_categorical(Y_train, nb_classes)
Y_test = np_utils.to_categorical(Y_test, nb_classes)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (18806, 48)
# (13242, 48)
# (18806, 2)
# (13242, 2)

# %% [markdown]
# # <6-3. AI 모델 디자인>

# %%
from keras.models import Sequential

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=48))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(nb_classes, activation='sigmoid'))

model_checkpoint = ModelCheckpoint('weight_CNC_binary.mat', monitor='val_acc',save_best_only=True)
opt=Adam(lr)
model.summary()
model.compile(optimizer=opt,loss='binary_crossentropy',
              metrics=['accuracy'])
history = History()
print('.............................model is defined.............................')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4244/1999992281.py in <module>
#       1 from keras.models import Sequential
#       2
# ----> 3 model = Sequential()
#       4 model.add(Dense(128, activation='relu', input_dim=48))
#       5 model.add(Dropout(0.3))
#
# ~\anaconda3\lib\site-packages\keras\models.py in __init__(self, layers, name)
#     433         if not name:
#     434             prefix = 'sequential_'
# --> 435             name = prefix + str(K.get_uid(prefix))
#     436         self.name = name
#     437
#
# ~\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_uid(prefix)
#      66     """
#      67     global _GRAPH_UID_DICTS
# ---> 68     graph = tf.get_default_graph()
#      69     if graph not in _GRAPH_UID_DICTS:
#      70         _GRAPH_UID_DICTS[graph] = defaultdict(int)
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'

# %% [markdown]
# # <7-1. AI 모델 훈련>

# %%
model.fit(X_train, Y_train, verbose=2, batch_size=batch_size, epochs=epochs, validation_split=0.1, shuffle=True, callbacks=[history])
model.save_weights('weight_CNC_binary.mat')
# Out:
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:977: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:964: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2503: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 16925 samples, validate on 1881 samples
# Epoch 1/300
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:168: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:175: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:184: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:193: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\adminstrator\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:200: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 1s - loss: 0.6860 - acc: 0.5448 - val_loss: 0.7780 - val_acc: 0.0000e+00
# Epoch 2/300
#  - 0s - loss: 0.6763 - acc: 0.5567 - val_loss: 0.7819 - val_acc: 0.0088
# Epoch 3/300
#  - 0s - loss: 0.6625 - acc: 0.5684 - val_loss: 0.7602 - val_acc: 0.5199
# Epoch 4/300
#  - 0s - loss: 0.6400 - acc: 0.6260 - val_loss: 0.7127 - val_acc: 0.6768
# Epoch 5/300
#  - 0s - loss: 0.6181 - acc: 0.6612 - val_loss: 0.6135 - val_acc: 0.8357
# Epoch 6/300
#  - 0s - loss: 0.5959 - acc: 0.6796 - val_loss: 0.5786 - val_acc: 0.8711
# Epoch 7/300
#  - 0s - loss: 0.5735 - acc: 0.6981 - val_loss: 0.5221 - val_acc: 0.9141
# Epoch 8/300
#  - 0s - loss: 0.5461 - acc: 0.7122 - val_loss: 0.4380 - val_acc: 0.9830
# Epoch 9/300
#  - 0s - loss: 0.5166 - acc: 0.7350 - val_loss: 0.4186 - val_acc: 0.9785
# Epoch 10/300
#  - 0s - loss: 0.4899 - acc: 0.7591 - val_loss: 0.3892 - val_acc: 0.9830
# Epoch 11/300
#  - 0s - loss: 0.4639 - acc: 0.7742 - val_loss: 0.3689 - val_acc: 0.9822
# Epoch 12/300
#  - 0s - loss: 0.4497 - acc: 0.7881 - val_loss: 0.3440 - val_acc: 0.9880
# Epoch 13/300
#  - 0s - loss: 0.4327 - acc: 0.8033 - val_loss: 0.3314 - val_acc: 0.9851
# Epoch 14/300
#  - 0s - loss: 0.4160 - acc: 0.8131 - val_loss: 0.2944 - val_acc: 0.9766
# Epoch 15/300
#  - 0s - loss: 0.3954 - acc: 0.8253 - val_loss: 0.3082 - val_acc: 0.8822
# Epoch 16/300
#  - 0s - loss: 0.3853 - acc: 0.8353 - val_loss: 0.2869 - val_acc: 0.8905
# Epoch 17/300
#  - 0s - loss: 0.3653 - acc: 0.8456 - val_loss: 0.2474 - val_acc: 0.9110
# Epoch 18/300
#  - 0s - loss: 0.3556 - acc: 0.8517 - val_loss: 0.2327 - val_acc: 0.9059
# Epoch 19/300
#  - 0s - loss: 0.3403 - acc: 0.8588 - val_loss: 0.2211 - val_acc: 0.9107
# Epoch 20/300
#  - 0s - loss: 0.3325 - acc: 0.8588 - val_loss: 0.1978 - val_acc: 0.9181
# Epoch 21/300
#  - 0s - loss: 0.3212 - acc: 0.8667 - val_loss: 0.1876 - val_acc: 0.9229
# Epoch 22/300
#  - 0s - loss: 0.3065 - acc: 0.8732 - val_loss: 0.2204 - val_acc: 0.9062
# Epoch 23/300
#  - 0s - loss: 0.2958 - acc: 0.8790 - val_loss: 0.2211 - val_acc: 0.9070
# Epoch 24/300
#  - 0s - loss: 0.2880 - acc: 0.8814 - val_loss: 0.1710 - val_acc: 0.9112
# Epoch 25/300
#  - 0s - loss: 0.2760 - acc: 0.8861 - val_loss: 0.2202 - val_acc: 0.9080
# Epoch 26/300
#  - 0s - loss: 0.2762 - acc: 0.8853 - val_loss: 0.2419 - val_acc: 0.8971
# Epoch 27/300
#  - 0s - loss: 0.2609 - acc: 0.8919 - val_loss: 0.2337 - val_acc: 0.8985
# Epoch 28/300
#  - 0s - loss: 0.2524 - acc: 0.8985 - val_loss: 0.2053 - val_acc: 0.9040
# Epoch 29/300
#  - 0s - loss: 0.2486 - acc: 0.8980 - val_loss: 0.2479 - val_acc: 0.8934
# Epoch 30/300
#  - 0s - loss: 0.2431 - acc: 0.9023 - val_loss: 0.2288 - val_acc: 0.9014
# Epoch 31/300
#  - 0s - loss: 0.2340 - acc: 0.9045 - val_loss: 0.2860 - val_acc: 0.8604
# Epoch 32/300
#  - 0s - loss: 0.2271 - acc: 0.9088 - val_loss: 0.2859 - val_acc: 0.8820
# Epoch 33/300
#  - 0s - loss: 0.2263 - acc: 0.9069 - val_loss: 0.2883 - val_acc: 0.8791
# Epoch 34/300
#  - 0s - loss: 0.2136 - acc: 0.9134 - val_loss: 0.2499 - val_acc: 0.8892
# Epoch 35/300
#  - 0s - loss: 0.2116 - acc: 0.9163 - val_loss: 0.3096 - val_acc: 0.8602
# Epoch 36/300
#  - 0s - loss: 0.2062 - acc: 0.9151 - val_loss: 0.3400 - val_acc: 0.8448
# Epoch 37/300
#  - 0s - loss: 0.2049 - acc: 0.9169 - val_loss: 0.3974 - val_acc: 0.7876
# Epoch 38/300
#  - 0s - loss: 0.2018 - acc: 0.9173 - val_loss: 0.4494 - val_acc: 0.7815
# Epoch 39/300
#  - 0s - loss: 0.1973 - acc: 0.9204 - val_loss: 0.3728 - val_acc: 0.8195
# Epoch 40/300
#  - 0s - loss: 0.1915 - acc: 0.9215 - val_loss: 0.4131 - val_acc: 0.7919
# Epoch 41/300
#  - 0s - loss: 0.1912 - acc: 0.9206 - val_loss: 0.4449 - val_acc: 0.7868
# Epoch 42/300
#  - 0s - loss: 0.1888 - acc: 0.9213 - val_loss: 0.3953 - val_acc: 0.8142
# Epoch 43/300
#  - 0s - loss: 0.1784 - acc: 0.9283 - val_loss: 0.5207 - val_acc: 0.7818
# Epoch 44/300
#  - 0s - loss: 0.1779 - acc: 0.9281 - val_loss: 0.4548 - val_acc: 0.7873
# Epoch 45/300
#  - 0s - loss: 0.1718 - acc: 0.9282 - val_loss: 0.5243 - val_acc: 0.7812
# Epoch 46/300
#  - 0s - loss: 0.1728 - acc: 0.9282 - val_loss: 0.5713 - val_acc: 0.7767
# Epoch 47/300
#  - 0s - loss: 0.1746 - acc: 0.9293 - val_loss: 0.5547 - val_acc: 0.7796
# Epoch 48/300
#  - 0s - loss: 0.1669 - acc: 0.9316 - val_loss: 0.5586 - val_acc: 0.7815
# Epoch 49/300
#  - 0s - loss: 0.1626 - acc: 0.9315 - val_loss: 0.5704 - val_acc: 0.7807
# Epoch 50/300
#  - 0s - loss: 0.1649 - acc: 0.9326 - val_loss: 0.6158 - val_acc: 0.7738
# Epoch 51/300
#  - 0s - loss: 0.1574 - acc: 0.9342 - val_loss: 0.6218 - val_acc: 0.7786
# Epoch 52/300
#  - 0s - loss: 0.1590 - acc: 0.9347 - val_loss: 0.6496 - val_acc: 0.7719
# Epoch 53/300
#  - 0s - loss: 0.1603 - acc: 0.9340 - val_loss: 0.6398 - val_acc: 0.7722
# Epoch 54/300
#  - 0s - loss: 0.1531 - acc: 0.9375 - val_loss: 0.6279 - val_acc: 0.7749
# Epoch 55/300
#  - 0s - loss: 0.1503 - acc: 0.9374 - val_loss: 0.6720 - val_acc: 0.7735
# Epoch 56/300
#  - 0s - loss: 0.1530 - acc: 0.9371 - val_loss: 0.7161 - val_acc: 0.7677
# Epoch 57/300
#  - 0s - loss: 0.1493 - acc: 0.9382 - val_loss: 0.7317 - val_acc: 0.7709
# Epoch 58/300
#  - 0s - loss: 0.1420 - acc: 0.9407 - val_loss: 0.7770 - val_acc: 0.7682
# Epoch 59/300
#  - 0s - loss: 0.1393 - acc: 0.9417 - val_loss: 0.7397 - val_acc: 0.7714
# Epoch 60/300
#  - 0s - loss: 0.1407 - acc: 0.9405 - val_loss: 0.8222 - val_acc: 0.7674
# Epoch 61/300
#  - 0s - loss: 0.1384 - acc: 0.9433 - val_loss: 0.7750 - val_acc: 0.7709
# Epoch 62/300
#  - 0s - loss: 0.1400 - acc: 0.9419 - val_loss: 0.7686 - val_acc: 0.7711
# Epoch 63/300
#  - 0s - loss: 0.1325 - acc: 0.9458 - val_loss: 0.8292 - val_acc: 0.7682
# Epoch 64/300
#  - 0s - loss: 0.1373 - acc: 0.9410 - val_loss: 0.8109 - val_acc: 0.7714
# Epoch 65/300
#  - 0s - loss: 0.1324 - acc: 0.9450 - val_loss: 0.8037 - val_acc: 0.7722
# Epoch 66/300
#  - 0s - loss: 0.1321 - acc: 0.9438 - val_loss: 0.8666 - val_acc: 0.7674
# Epoch 67/300
#  - 0s - loss: 0.1307 - acc: 0.9459 - val_loss: 0.9081 - val_acc: 0.7661
# Epoch 68/300
#  - 0s - loss: 0.1288 - acc: 0.9448 - val_loss: 0.9079 - val_acc: 0.7661
# Epoch 69/300
#  - 0s - loss: 0.1291 - acc: 0.9466 - val_loss: 0.8961 - val_acc: 0.7703
# Epoch 70/300
#  - 0s - loss: 0.1236 - acc: 0.9480 - val_loss: 0.9258 - val_acc: 0.7677
# Epoch 71/300
#  - 0s - loss: 0.1237 - acc: 0.9486 - val_loss: 0.9312 - val_acc: 0.7671
# Epoch 72/300
#  - 0s - loss: 0.1234 - acc: 0.9483 - val_loss: 0.9028 - val_acc: 0.7709
# Epoch 73/300
#  - 0s - loss: 0.1196 - acc: 0.9508 - val_loss: 0.9494 - val_acc: 0.7693
# Epoch 74/300
#  - 0s - loss: 0.1224 - acc: 0.9486 - val_loss: 0.9013 - val_acc: 0.7711
# Epoch 75/300
#  - 0s - loss: 0.1201 - acc: 0.9525 - val_loss: 0.9820 - val_acc: 0.7656
# Epoch 76/300
#  - 0s - loss: 0.1169 - acc: 0.9501 - val_loss: 0.9923 - val_acc: 0.7671
# Epoch 77/300
#  - 0s - loss: 0.1137 - acc: 0.9524 - val_loss: 1.0188 - val_acc: 0.7666
# Epoch 78/300
#  - 1s - loss: 0.1175 - acc: 0.9492 - val_loss: 1.0235 - val_acc: 0.7642
# Epoch 79/300
#  - 0s - loss: 0.1168 - acc: 0.9518 - val_loss: 1.1300 - val_acc: 0.7645
# Epoch 80/300
#  - 0s - loss: 0.1103 - acc: 0.9544 - val_loss: 1.1186 - val_acc: 0.7650
# Epoch 81/300
#  - 0s - loss: 0.1093 - acc: 0.9531 - val_loss: 1.0052 - val_acc: 0.7698
# Epoch 82/300
#  - 0s - loss: 0.1077 - acc: 0.9556 - val_loss: 1.1396 - val_acc: 0.7671
# Epoch 83/300
#  - 0s - loss: 0.1107 - acc: 0.9542 - val_loss: 1.0374 - val_acc: 0.7709
# Epoch 84/300
#  - 0s - loss: 0.1051 - acc: 0.9559 - val_loss: 1.1643 - val_acc: 0.7666
# Epoch 85/300
#  - 0s - loss: 0.1079 - acc: 0.9555 - val_loss: 1.0580 - val_acc: 0.7698
# Epoch 86/300
#  - 0s - loss: 0.1083 - acc: 0.9545 - val_loss: 1.1433 - val_acc: 0.7663
# Epoch 87/300
#  - 0s - loss: 0.1059 - acc: 0.9559 - val_loss: 1.1369 - val_acc: 0.7677
# Epoch 88/300
#  - 0s - loss: 0.1068 - acc: 0.9545 - val_loss: 1.1892 - val_acc: 0.7656
# Epoch 89/300
#  - 0s - loss: 0.0998 - acc: 0.9581 - val_loss: 1.1620 - val_acc: 0.7677
# Epoch 90/300
#  - 0s - loss: 0.1006 - acc: 0.9577 - val_loss: 1.1679 - val_acc: 0.7677
# Epoch 91/300
#  - 0s - loss: 0.1019 - acc: 0.9566 - val_loss: 1.2446 - val_acc: 0.7661
# Epoch 92/300
#  - 0s - loss: 0.0989 - acc: 0.9573 - val_loss: 1.2810 - val_acc: 0.7626
# Epoch 93/300
#  - 0s - loss: 0.0971 - acc: 0.9590 - val_loss: 1.3678 - val_acc: 0.7624
# Epoch 94/300
#  - 0s - loss: 0.1002 - acc: 0.9581 - val_loss: 1.2776 - val_acc: 0.7658
# Epoch 95/300
#  - 0s - loss: 0.0990 - acc: 0.9583 - val_loss: 1.2920 - val_acc: 0.7656
# Epoch 96/300
#  - 0s - loss: 0.0928 - acc: 0.9612 - val_loss: 1.3257 - val_acc: 0.7679
# Epoch 97/300
#  - 0s - loss: 0.0971 - acc: 0.9593 - val_loss: 1.2622 - val_acc: 0.7658
# Epoch 98/300
#  - 0s - loss: 0.0949 - acc: 0.9604 - val_loss: 1.2295 - val_acc: 0.7671
# Epoch 99/300
#  - 0s - loss: 0.0968 - acc: 0.9585 - val_loss: 1.2173 - val_acc: 0.7671
# Epoch 100/300
#  - 0s - loss: 0.0945 - acc: 0.9597 - val_loss: 1.3086 - val_acc: 0.7677
# Epoch 101/300
#  - 0s - loss: 0.0877 - acc: 0.9625 - val_loss: 1.3424 - val_acc: 0.7656
# Epoch 102/300
#  - 0s - loss: 0.0924 - acc: 0.9609 - val_loss: 1.3711 - val_acc: 0.7656
# Epoch 103/300
#  - 0s - loss: 0.0907 - acc: 0.9614 - val_loss: 1.3442 - val_acc: 0.7658
# Epoch 104/300
#  - 0s - loss: 0.0891 - acc: 0.9617 - val_loss: 1.4673 - val_acc: 0.7645
# Epoch 105/300
#  - 0s - loss: 0.0929 - acc: 0.9603 - val_loss: 1.3479 - val_acc: 0.7661
# Epoch 106/300
#  - 0s - loss: 0.0867 - acc: 0.9619 - val_loss: 1.4154 - val_acc: 0.7656
# Epoch 107/300
#  - 0s - loss: 0.0861 - acc: 0.9631 - val_loss: 1.3103 - val_acc: 0.7677
# Epoch 108/300
#  - 0s - loss: 0.0852 - acc: 0.9639 - val_loss: 1.4277 - val_acc: 0.7663
# Epoch 109/300
#  - 0s - loss: 0.0841 - acc: 0.9625 - val_loss: 1.4648 - val_acc: 0.7671
# Epoch 110/300
#  - 0s - loss: 0.0838 - acc: 0.9646 - val_loss: 1.5102 - val_acc: 0.7645
# Epoch 111/300
#  - 1s - loss: 0.0848 - acc: 0.9641 - val_loss: 1.4910 - val_acc: 0.7671
# Epoch 112/300
#  - 0s - loss: 0.0843 - acc: 0.9654 - val_loss: 1.5898 - val_acc: 0.7663
# Epoch 113/300
#  - 0s - loss: 0.0829 - acc: 0.9653 - val_loss: 1.5912 - val_acc: 0.7650
# Epoch 114/300
#  - 0s - loss: 0.0825 - acc: 0.9645 - val_loss: 1.5244 - val_acc: 0.7666
# Epoch 115/300
#  - 0s - loss: 0.0793 - acc: 0.9656 - val_loss: 1.5377 - val_acc: 0.7677
# Epoch 116/300
#  - 0s - loss: 0.0786 - acc: 0.9658 - val_loss: 1.6090 - val_acc: 0.7648
# Epoch 117/300
#  - 0s - loss: 0.0818 - acc: 0.9651 - val_loss: 1.6191 - val_acc: 0.7656
# Epoch 118/300
#  - 0s - loss: 0.0831 - acc: 0.9653 - val_loss: 1.5242 - val_acc: 0.7677
# Epoch 119/300
#  - 0s - loss: 0.0819 - acc: 0.9652 - val_loss: 1.5442 - val_acc: 0.7690
# Epoch 120/300
#  - 0s - loss: 0.0814 - acc: 0.9667 - val_loss: 1.5193 - val_acc: 0.7666
# Epoch 121/300
#  - 0s - loss: 0.0811 - acc: 0.9663 - val_loss: 1.5018 - val_acc: 0.7666
# Epoch 122/300
#  - 0s - loss: 0.0800 - acc: 0.9664 - val_loss: 1.6120 - val_acc: 0.7650
# Epoch 123/300
#  - 0s - loss: 0.0783 - acc: 0.9668 - val_loss: 1.5924 - val_acc: 0.7656
# Epoch 124/300
#  - 0s - loss: 0.0773 - acc: 0.9680 - val_loss: 1.7012 - val_acc: 0.7645
# Epoch 125/300
#  - 0s - loss: 0.0783 - acc: 0.9669 - val_loss: 1.6591 - val_acc: 0.7650
# Epoch 126/300
#  - 0s - loss: 0.0768 - acc: 0.9669 - val_loss: 1.7422 - val_acc: 0.7650
# Epoch 127/300
#  - 0s - loss: 0.0760 - acc: 0.9671 - val_loss: 1.7560 - val_acc: 0.7658
# Epoch 128/300
#  - 0s - loss: 0.0766 - acc: 0.9677 - val_loss: 1.6081 - val_acc: 0.7682
# Epoch 129/300
#  - 0s - loss: 0.0715 - acc: 0.9672 - val_loss: 1.7185 - val_acc: 0.7666
# Epoch 130/300
#  - 0s - loss: 0.0747 - acc: 0.9676 - val_loss: 1.7179 - val_acc: 0.7674
# Epoch 131/300
#  - 0s - loss: 0.0717 - acc: 0.9687 - val_loss: 1.7630 - val_acc: 0.7671
# Epoch 132/300
#  - 0s - loss: 0.0679 - acc: 0.9713 - val_loss: 1.8384 - val_acc: 0.7663
# Epoch 133/300
#  - 0s - loss: 0.0701 - acc: 0.9704 - val_loss: 1.8368 - val_acc: 0.7656
# Epoch 134/300
#  - 0s - loss: 0.0688 - acc: 0.9703 - val_loss: 2.0051 - val_acc: 0.7656
# Epoch 135/300
#  - 0s - loss: 0.0694 - acc: 0.9719 - val_loss: 1.9053 - val_acc: 0.7645
# Epoch 136/300
#  - 0s - loss: 0.0718 - acc: 0.9697 - val_loss: 1.9669 - val_acc: 0.7645
# Epoch 137/300
#  - 0s - loss: 0.0693 - acc: 0.9705 - val_loss: 1.8022 - val_acc: 0.7671
# Epoch 138/300
#  - 0s - loss: 0.0682 - acc: 0.9721 - val_loss: 1.8350 - val_acc: 0.7666
# Epoch 139/300
#  - 0s - loss: 0.0697 - acc: 0.9691 - val_loss: 1.9192 - val_acc: 0.7661
# Epoch 140/300
#  - 0s - loss: 0.0661 - acc: 0.9709 - val_loss: 1.7223 - val_acc: 0.7690
# Epoch 141/300
#  - 0s - loss: 0.0688 - acc: 0.9716 - val_loss: 1.7747 - val_acc: 0.7695
# Epoch 142/300
#  - 0s - loss: 0.0696 - acc: 0.9701 - val_loss: 1.7574 - val_acc: 0.7666
# Epoch 143/300
#  - 0s - loss: 0.0673 - acc: 0.9721 - val_loss: 1.9671 - val_acc: 0.7679
# Epoch 144/300
#  - 0s - loss: 0.0694 - acc: 0.9707 - val_loss: 1.7457 - val_acc: 0.7677
# Epoch 145/300
#  - 0s - loss: 0.0649 - acc: 0.9721 - val_loss: 1.9753 - val_acc: 0.7650
# Epoch 146/300
#  - 0s - loss: 0.0672 - acc: 0.9703 - val_loss: 1.9268 - val_acc: 0.7661
# Epoch 147/300
#  - 0s - loss: 0.0637 - acc: 0.9724 - val_loss: 2.0021 - val_acc: 0.7656
# Epoch 148/300
#  - 0s - loss: 0.0655 - acc: 0.9734 - val_loss: 1.9728 - val_acc: 0.7671
# Epoch 149/300
#  - 0s - loss: 0.0655 - acc: 0.9713 - val_loss: 1.8532 - val_acc: 0.7687
# Epoch 150/300
#  - 0s - loss: 0.0591 - acc: 0.9747 - val_loss: 1.8354 - val_acc: 0.7698
# Epoch 151/300
#  - 0s - loss: 0.0663 - acc: 0.9714 - val_loss: 1.9703 - val_acc: 0.7666
# Epoch 152/300
#  - 0s - loss: 0.0649 - acc: 0.9731 - val_loss: 1.7543 - val_acc: 0.7685
# Epoch 153/300
#  - 0s - loss: 0.0634 - acc: 0.9736 - val_loss: 1.8594 - val_acc: 0.7687
# Epoch 154/300
#  - 0s - loss: 0.0630 - acc: 0.9731 - val_loss: 1.9161 - val_acc: 0.7661
# Epoch 155/300
#  - 0s - loss: 0.0634 - acc: 0.9729 - val_loss: 1.8504 - val_acc: 0.7687
# Epoch 156/300
#  - 0s - loss: 0.0596 - acc: 0.9741 - val_loss: 1.8379 - val_acc: 0.7698
# Epoch 157/300
#  - 0s - loss: 0.0602 - acc: 0.9751 - val_loss: 1.9288 - val_acc: 0.7677
# Epoch 158/300
#  - 0s - loss: 0.0604 - acc: 0.9747 - val_loss: 2.0194 - val_acc: 0.7669
# Epoch 159/300
#  - 0s - loss: 0.0599 - acc: 0.9747 - val_loss: 1.8953 - val_acc: 0.7677
# Epoch 160/300
#  - 0s - loss: 0.0599 - acc: 0.9737 - val_loss: 1.8845 - val_acc: 0.7693
# Epoch 161/300
#  - 0s - loss: 0.0614 - acc: 0.9748 - val_loss: 1.9446 - val_acc: 0.7674
# Epoch 162/300
#  - 0s - loss: 0.0578 - acc: 0.9757 - val_loss: 1.8908 - val_acc: 0.7698
# Epoch 163/300
#  - 0s - loss: 0.0592 - acc: 0.9746 - val_loss: 2.0364 - val_acc: 0.7677
# Epoch 164/300
#  - 0s - loss: 0.0586 - acc: 0.9755 - val_loss: 1.8971 - val_acc: 0.7703
# Epoch 165/300
#  - 0s - loss: 0.0623 - acc: 0.9739 - val_loss: 1.9092 - val_acc: 0.7671
# Epoch 166/300
#  - 0s - loss: 0.0550 - acc: 0.9776 - val_loss: 1.9612 - val_acc: 0.7693
# Epoch 167/300
#  - 0s - loss: 0.0590 - acc: 0.9755 - val_loss: 1.9566 - val_acc: 0.7687
# Epoch 168/300
#  - 0s - loss: 0.0571 - acc: 0.9773 - val_loss: 2.0529 - val_acc: 0.7698
# Epoch 169/300
#  - 0s - loss: 0.0559 - acc: 0.9762 - val_loss: 2.0946 - val_acc: 0.7693
# Epoch 170/300
#  - 0s - loss: 0.0579 - acc: 0.9764 - val_loss: 2.0779 - val_acc: 0.7682
# Epoch 171/300
#  - 0s - loss: 0.0557 - acc: 0.9768 - val_loss: 1.9880 - val_acc: 0.7682
# Epoch 172/300
#  - 0s - loss: 0.0553 - acc: 0.9755 - val_loss: 1.9995 - val_acc: 0.7693
# Epoch 173/300
#  - 0s - loss: 0.0547 - acc: 0.9769 - val_loss: 2.0962 - val_acc: 0.7671
# Epoch 174/300
#  - 0s - loss: 0.0568 - acc: 0.9751 - val_loss: 2.0662 - val_acc: 0.7671
# Epoch 175/300
#  - 0s - loss: 0.0564 - acc: 0.9773 - val_loss: 2.0347 - val_acc: 0.7666
# Epoch 176/300
#  - 0s - loss: 0.0538 - acc: 0.9779 - val_loss: 2.0009 - val_acc: 0.7682
# Epoch 177/300
#  - 0s - loss: 0.0559 - acc: 0.9773 - val_loss: 2.1378 - val_acc: 0.7674
# Epoch 178/300
#  - 0s - loss: 0.0550 - acc: 0.9779 - val_loss: 2.0149 - val_acc: 0.7693
# Epoch 179/300
#  - 0s - loss: 0.0507 - acc: 0.9778 - val_loss: 2.0891 - val_acc: 0.7671
# Epoch 180/300
#  - 0s - loss: 0.0521 - acc: 0.9786 - val_loss: 2.0908 - val_acc: 0.7677
# Epoch 181/300
#  - 0s - loss: 0.0511 - acc: 0.9776 - val_loss: 2.1201 - val_acc: 0.7671
# Epoch 182/300
#  - 0s - loss: 0.0518 - acc: 0.9788 - val_loss: 2.0770 - val_acc: 0.7682
# Epoch 183/300
#  - 0s - loss: 0.0519 - acc: 0.9778 - val_loss: 2.1663 - val_acc: 0.7677
# Epoch 184/300
#  - 0s - loss: 0.0545 - acc: 0.9759 - val_loss: 2.2000 - val_acc: 0.7666
# Epoch 185/300
#  - 0s - loss: 0.0490 - acc: 0.9792 - val_loss: 2.1871 - val_acc: 0.7687
# Epoch 186/300
#  - 0s - loss: 0.0503 - acc: 0.9790 - val_loss: 2.0440 - val_acc: 0.7698
# Epoch 187/300
#  - 0s - loss: 0.0493 - acc: 0.9789 - val_loss: 2.1738 - val_acc: 0.7693
# Epoch 188/300
#  - 0s - loss: 0.0500 - acc: 0.9782 - val_loss: 2.0654 - val_acc: 0.7698
# Epoch 189/300
#  - 0s - loss: 0.0526 - acc: 0.9786 - val_loss: 2.2741 - val_acc: 0.7666
# Epoch 190/300
#  - 0s - loss: 0.0496 - acc: 0.9799 - val_loss: 2.1948 - val_acc: 0.7687
# Epoch 191/300
#  - 0s - loss: 0.0514 - acc: 0.9799 - val_loss: 2.1370 - val_acc: 0.7698
# Epoch 192/300
#  - 0s - loss: 0.0491 - acc: 0.9808 - val_loss: 2.3110 - val_acc: 0.7656
# Epoch 193/300
#  - 0s - loss: 0.0482 - acc: 0.9791 - val_loss: 2.2317 - val_acc: 0.7671
# Epoch 194/300
#  - 0s - loss: 0.0494 - acc: 0.9812 - val_loss: 2.1972 - val_acc: 0.7677
# Epoch 195/300
#  - 0s - loss: 0.0491 - acc: 0.9792 - val_loss: 2.2105 - val_acc: 0.7671
# Epoch 196/300
#  - 0s - loss: 0.0501 - acc: 0.9799 - val_loss: 2.1150 - val_acc: 0.7693
# Epoch 197/300
#  - 0s - loss: 0.0471 - acc: 0.9804 - val_loss: 2.2211 - val_acc: 0.7682
# Epoch 198/300
#  - 0s - loss: 0.0479 - acc: 0.9804 - val_loss: 2.3267 - val_acc: 0.7677
# Epoch 199/300
#  - 0s - loss: 0.0482 - acc: 0.9791 - val_loss: 2.1842 - val_acc: 0.7679
# Epoch 200/300
#  - 0s - loss: 0.0428 - acc: 0.9812 - val_loss: 2.3841 - val_acc: 0.7674
# Epoch 201/300
#  - 0s - loss: 0.0505 - acc: 0.9797 - val_loss: 2.2605 - val_acc: 0.7677
# Epoch 202/300
#  - 0s - loss: 0.0445 - acc: 0.9815 - val_loss: 2.4015 - val_acc: 0.7677
# Epoch 203/300
#  - 0s - loss: 0.0492 - acc: 0.9789 - val_loss: 2.3401 - val_acc: 0.7693
# Epoch 204/300
#  - 0s - loss: 0.0469 - acc: 0.9809 - val_loss: 2.3615 - val_acc: 0.7677
# Epoch 205/300
#  - 0s - loss: 0.0488 - acc: 0.9798 - val_loss: 2.3742 - val_acc: 0.7666
# Epoch 206/300
#  - 0s - loss: 0.0414 - acc: 0.9833 - val_loss: 2.4592 - val_acc: 0.7661
# Epoch 207/300
#  - 0s - loss: 0.0465 - acc: 0.9806 - val_loss: 2.2028 - val_acc: 0.7682
# Epoch 208/300
#  - 0s - loss: 0.0452 - acc: 0.9814 - val_loss: 2.2404 - val_acc: 0.7682
# Epoch 209/300
#  - 0s - loss: 0.0460 - acc: 0.9802 - val_loss: 2.4497 - val_acc: 0.7671
# Epoch 210/300
#  - 0s - loss: 0.0495 - acc: 0.9803 - val_loss: 2.2794 - val_acc: 0.7666
# Epoch 211/300
#  - 0s - loss: 0.0437 - acc: 0.9816 - val_loss: 2.1046 - val_acc: 0.7698
# Epoch 212/300
#  - 0s - loss: 0.0451 - acc: 0.9812 - val_loss: 2.2974 - val_acc: 0.7677
# Epoch 213/300
#  - 0s - loss: 0.0441 - acc: 0.9817 - val_loss: 2.2502 - val_acc: 0.7693
# Epoch 214/300
#  - 0s - loss: 0.0455 - acc: 0.9810 - val_loss: 2.2727 - val_acc: 0.7671
# Epoch 215/300
#  - 0s - loss: 0.0455 - acc: 0.9794 - val_loss: 2.3892 - val_acc: 0.7677
# Epoch 216/300
#  - 0s - loss: 0.0445 - acc: 0.9818 - val_loss: 2.4209 - val_acc: 0.7671
# Epoch 217/300
#  - 0s - loss: 0.0422 - acc: 0.9817 - val_loss: 2.3963 - val_acc: 0.7682
# Epoch 218/300
#  - 0s - loss: 0.0457 - acc: 0.9816 - val_loss: 2.3885 - val_acc: 0.7677
# Epoch 219/300
#  - 0s - loss: 0.0445 - acc: 0.9809 - val_loss: 2.4881 - val_acc: 0.7666
# Epoch 220/300
#  - 0s - loss: 0.0444 - acc: 0.9819 - val_loss: 2.3326 - val_acc: 0.7682
# Epoch 221/300
#  - 0s - loss: 0.0471 - acc: 0.9806 - val_loss: 2.4461 - val_acc: 0.7679
# Epoch 222/300
#  - 0s - loss: 0.0435 - acc: 0.9819 - val_loss: 2.4030 - val_acc: 0.7687
# Epoch 223/300
#  - 0s - loss: 0.0439 - acc: 0.9817 - val_loss: 2.4405 - val_acc: 0.7687
# Epoch 224/300
#  - 0s - loss: 0.0453 - acc: 0.9804 - val_loss: 2.5393 - val_acc: 0.7682
# Epoch 225/300
#  - 0s - loss: 0.0410 - acc: 0.9836 - val_loss: 2.5643 - val_acc: 0.7682
# Epoch 226/300
#  - 0s - loss: 0.0431 - acc: 0.9816 - val_loss: 2.4756 - val_acc: 0.7682
# Epoch 227/300
#  - 0s - loss: 0.0435 - acc: 0.9817 - val_loss: 2.4339 - val_acc: 0.7682
# Epoch 228/300
#  - 0s - loss: 0.0454 - acc: 0.9814 - val_loss: 2.1882 - val_acc: 0.7703
# Epoch 229/300
#  - 0s - loss: 0.0433 - acc: 0.9815 - val_loss: 2.5502 - val_acc: 0.7661
# Epoch 230/300
#  - 0s - loss: 0.0419 - acc: 0.9830 - val_loss: 2.3436 - val_acc: 0.7666
# Epoch 231/300
#  - 0s - loss: 0.0421 - acc: 0.9821 - val_loss: 2.3783 - val_acc: 0.7674
# Epoch 232/300
#  - 0s - loss: 0.0396 - acc: 0.9842 - val_loss: 2.5871 - val_acc: 0.7656
# Epoch 233/300
#  - 0s - loss: 0.0379 - acc: 0.9842 - val_loss: 2.5375 - val_acc: 0.7666
# Epoch 234/300
#  - 0s - loss: 0.0377 - acc: 0.9843 - val_loss: 2.5777 - val_acc: 0.7666
# Epoch 235/300
#  - 0s - loss: 0.0419 - acc: 0.9830 - val_loss: 2.5627 - val_acc: 0.7666
# Epoch 236/300
#  - 0s - loss: 0.0407 - acc: 0.9838 - val_loss: 2.5843 - val_acc: 0.7666
# Epoch 237/300
#  - 0s - loss: 0.0386 - acc: 0.9838 - val_loss: 2.6312 - val_acc: 0.7666
# Epoch 238/300
#  - 0s - loss: 0.0415 - acc: 0.9832 - val_loss: 2.5165 - val_acc: 0.7677
# Epoch 239/300
#  - 0s - loss: 0.0426 - acc: 0.9820 - val_loss: 2.4164 - val_acc: 0.7687
# Epoch 240/300
#  - 0s - loss: 0.0395 - acc: 0.9841 - val_loss: 2.6651 - val_acc: 0.7693
# Epoch 241/300
#  - 0s - loss: 0.0364 - acc: 0.9845 - val_loss: 2.5574 - val_acc: 0.7693
# Epoch 242/300
#  - 0s - loss: 0.0387 - acc: 0.9839 - val_loss: 2.7407 - val_acc: 0.7650
# Epoch 243/300
#  - 0s - loss: 0.0423 - acc: 0.9819 - val_loss: 2.4880 - val_acc: 0.7682
# Epoch 244/300
#  - 0s - loss: 0.0363 - acc: 0.9848 - val_loss: 2.5783 - val_acc: 0.7671
# Epoch 245/300
#  - 0s - loss: 0.0359 - acc: 0.9845 - val_loss: 2.6545 - val_acc: 0.7671
# Epoch 246/300
#  - 0s - loss: 0.0391 - acc: 0.9833 - val_loss: 2.5631 - val_acc: 0.7682
# Epoch 247/300
#  - 0s - loss: 0.0396 - acc: 0.9834 - val_loss: 2.5277 - val_acc: 0.7687
# Epoch 248/300
#  - 0s - loss: 0.0398 - acc: 0.9839 - val_loss: 2.6587 - val_acc: 0.7671
# Epoch 249/300
#  - 0s - loss: 0.0394 - acc: 0.9842 - val_loss: 2.4984 - val_acc: 0.7687
# Epoch 250/300
#  - 0s - loss: 0.0382 - acc: 0.9845 - val_loss: 2.5461 - val_acc: 0.7663
# Epoch 251/300
#  - 0s - loss: 0.0392 - acc: 0.9837 - val_loss: 2.4471 - val_acc: 0.7693
# Epoch 252/300
#  - 0s - loss: 0.0390 - acc: 0.9836 - val_loss: 2.7116 - val_acc: 0.7671
# Epoch 253/300
#  - 0s - loss: 0.0373 - acc: 0.9851 - val_loss: 2.5489 - val_acc: 0.7677
# Epoch 254/300
#  - 0s - loss: 0.0386 - acc: 0.9844 - val_loss: 2.7545 - val_acc: 0.7661
# Epoch 255/300
#  - 0s - loss: 0.0366 - acc: 0.9848 - val_loss: 2.5432 - val_acc: 0.7687
# Epoch 256/300
#  - 0s - loss: 0.0374 - acc: 0.9834 - val_loss: 2.5338 - val_acc: 0.7690
# Epoch 257/300
#  - 0s - loss: 0.0367 - acc: 0.9856 - val_loss: 2.7789 - val_acc: 0.7661
# Epoch 258/300
#  - 0s - loss: 0.0357 - acc: 0.9851 - val_loss: 2.7042 - val_acc: 0.7656
# Epoch 259/300
#  - 0s - loss: 0.0371 - acc: 0.9851 - val_loss: 2.8952 - val_acc: 0.7650
# Epoch 260/300
#  - 0s - loss: 0.0399 - acc: 0.9838 - val_loss: 2.7702 - val_acc: 0.7650
# Epoch 261/300
#  - 0s - loss: 0.0388 - acc: 0.9845 - val_loss: 2.6002 - val_acc: 0.7671
# Epoch 262/300
#  - 0s - loss: 0.0382 - acc: 0.9847 - val_loss: 2.6777 - val_acc: 0.7656
# Epoch 263/300
#  - 0s - loss: 0.0350 - acc: 0.9851 - val_loss: 2.5099 - val_acc: 0.7671
# Epoch 264/300
#  - 0s - loss: 0.0398 - acc: 0.9838 - val_loss: 2.6805 - val_acc: 0.7656
# Epoch 265/300
#  - 0s - loss: 0.0344 - acc: 0.9863 - val_loss: 2.6726 - val_acc: 0.7656
# Epoch 266/300
#  - 0s - loss: 0.0394 - acc: 0.9848 - val_loss: 2.5585 - val_acc: 0.7671
# Epoch 267/300
#  - 0s - loss: 0.0355 - acc: 0.9851 - val_loss: 2.5211 - val_acc: 0.7658
# Epoch 268/300
#  - 0s - loss: 0.0362 - acc: 0.9848 - val_loss: 2.7600 - val_acc: 0.7640
# Epoch 269/300
#  - 0s - loss: 0.0343 - acc: 0.9853 - val_loss: 2.7543 - val_acc: 0.7656
# Epoch 270/300
#  - 0s - loss: 0.0352 - acc: 0.9856 - val_loss: 2.7071 - val_acc: 0.7677
# Epoch 271/300
#  - 0s - loss: 0.0355 - acc: 0.9862 - val_loss: 2.8710 - val_acc: 0.7666
# Epoch 272/300
#  - 0s - loss: 0.0364 - acc: 0.9856 - val_loss: 2.7009 - val_acc: 0.7661
# Epoch 273/300
#  - 0s - loss: 0.0364 - acc: 0.9854 - val_loss: 2.7668 - val_acc: 0.7682
# Epoch 274/300
#  - 0s - loss: 0.0373 - acc: 0.9843 - val_loss: 2.7917 - val_acc: 0.7656
# Epoch 275/300
#  - 0s - loss: 0.0354 - acc: 0.9856 - val_loss: 2.6139 - val_acc: 0.7677
# Epoch 276/300
#  - 0s - loss: 0.0352 - acc: 0.9853 - val_loss: 2.5311 - val_acc: 0.7666
# Epoch 277/300
#  - 0s - loss: 0.0343 - acc: 0.9861 - val_loss: 2.7288 - val_acc: 0.7666
# Epoch 278/300
#  - 0s - loss: 0.0346 - acc: 0.9857 - val_loss: 2.7967 - val_acc: 0.7656
# Epoch 279/300
#  - 0s - loss: 0.0337 - acc: 0.9859 - val_loss: 2.7338 - val_acc: 0.7650
# Epoch 280/300
#  - 0s - loss: 0.0360 - acc: 0.9844 - val_loss: 2.8540 - val_acc: 0.7650
# Epoch 281/300
#  - 0s - loss: 0.0327 - acc: 0.9861 - val_loss: 2.8489 - val_acc: 0.7671
# Epoch 282/300
#  - 0s - loss: 0.0345 - acc: 0.9867 - val_loss: 2.8185 - val_acc: 0.7666
# Epoch 283/300
#  - 0s - loss: 0.0339 - acc: 0.9860 - val_loss: 3.0185 - val_acc: 0.7656
# Epoch 284/300
#  - 0s - loss: 0.0334 - acc: 0.9866 - val_loss: 2.8585 - val_acc: 0.7661
# Epoch 285/300
#  - 0s - loss: 0.0339 - acc: 0.9857 - val_loss: 2.8249 - val_acc: 0.7671
# Epoch 286/300
#  - 0s - loss: 0.0356 - acc: 0.9857 - val_loss: 2.7483 - val_acc: 0.7640
# Epoch 287/300
#  - 0s - loss: 0.0340 - acc: 0.9865 - val_loss: 2.6898 - val_acc: 0.7640
# Epoch 288/300
#  - 0s - loss: 0.0328 - acc: 0.9865 - val_loss: 2.8625 - val_acc: 0.7645
# Epoch 289/300
#  - 0s - loss: 0.0337 - acc: 0.9862 - val_loss: 2.9684 - val_acc: 0.7656
# Epoch 290/300
#  - 0s - loss: 0.0336 - acc: 0.9858 - val_loss: 2.7901 - val_acc: 0.7666
# Epoch 291/300
#  - 0s - loss: 0.0325 - acc: 0.9872 - val_loss: 2.6708 - val_acc: 0.7632
# Epoch 292/300
#  - 0s - loss: 0.0353 - acc: 0.9861 - val_loss: 2.9411 - val_acc: 0.7629
# Epoch 293/300
#  - 0s - loss: 0.0341 - acc: 0.9858 - val_loss: 2.8820 - val_acc: 0.7661
# Epoch 294/300
#  - 0s - loss: 0.0336 - acc: 0.9858 - val_loss: 2.9020 - val_acc: 0.7640
# Epoch 295/300
#  - 0s - loss: 0.0323 - acc: 0.9866 - val_loss: 2.7379 - val_acc: 0.7650
# Epoch 296/300
#  - 0s - loss: 0.0325 - acc: 0.9857 - val_loss: 2.8288 - val_acc: 0.7661
# Epoch 297/300
#  - 0s - loss: 0.0322 - acc: 0.9868 - val_loss: 2.9065 - val_acc: 0.7661
# Epoch 298/300
#  - 0s - loss: 0.0293 - acc: 0.9882 - val_loss: 2.9483 - val_acc: 0.7650
# Epoch 299/300
#  - 0s - loss: 0.0311 - acc: 0.9871 - val_loss: 2.9315 - val_acc: 0.7656
# Epoch 300/300
#  - 0s - loss: 0.0312 - acc: 0.9865 - val_loss: 2.9224 - val_acc: 0.7656

# %% [markdown]
# # <8-1. AI 모델 훈련 결과 출력>

# %%
loss_and_metrics = model.evaluate(X_train,Y_train,batch_size=32)
print(loss_and_metrics)
# Out:
# 18806/18806 [==============================] - 0s 22us/step
# [0.30447130921144294, 0.9717111560140381]

# %%
loss_and_metrics2 = model.evaluate(X_test,Y_test,batch_size=32)
print(loss_and_metrics2)
# Out:
# 13242/13242 [==============================] - 0s 22us/step
# [0.8961000958438238, 0.9148164929768917]

# %%
# 해당 코드 실행 시 val_acc 또는 acc에서 오류 발생 시, 각각 val_accuracy 와 accuracy로 바꿔서 실행하도록 한다.
plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('Accuracy During Training')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Validation Accuracy','Training Accuracy'])

# %%
plt.plot(history.history['val_loss'])
plt.plot(history.history['loss'])
plt.title('Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Validation Loss','Training Loss'])
plt.show()
